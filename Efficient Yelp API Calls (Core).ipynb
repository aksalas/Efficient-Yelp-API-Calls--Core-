# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in c:\users\arvin\anaconda3\envs\dojo-env\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\arvin\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arvin\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arvin\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arvin\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arvin\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: tqdm in c:\users\arvin\anaconda3\envs\dojo-env\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\arvin\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.5)

# %%
with open('/Users/arvin/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['Client-ID', 'API Key'])

# %%
yelp = YelpAPI(login['API Key'], timeout_s =5.0)

# %%
location = 'Mundelein, IL 60060'
term = 'sushi'

# %%
location.split(',')[0]
# Out:
# 'Mundelein'

# %%
## Specify fodler for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Mundelein-sushi.json'

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder) > 0: 
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
        
## If it exists, inform user
else:
    print (f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Mundelein-sushi.json not found. Saving empty list to file.

# %%
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 37

# %%
results['region']
# Out:
# {'center': {'longitude': -88.0118179321289, 'latitude': 42.26052946261396}}

# %%
results['businesses']
# Out:
# [{'id': 'jmvm1_RdsaR37hgZwaFHug',
#   'alias': 'momo-sushi-mundelein-4',
#   'name': 'Momo sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mbrlz_kIE25EJW33DSTseA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/momo-sushi-mundelein-4?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 49,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.25337483, 'longitude': -88.00163317},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '662 S Lake St',
#    'address2': '',
#    'address3': None,
#    'city': 'Mundelein',
#    'zip_code': '60060',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['662 S Lake St', 'Mundelein, IL 60060']},
#   'phone': '+18475662544',
#   'display_phone': '(847) 566-2544',
#   'distance': 1158.8426223071233},
#  {'id': 'FRDeSt5dcTv4bEKuaAVgkg',
#   'alias': 'osaka-sushi-mundelein-2',
#   'name': 'Osaka Sushi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T93W-KaGXxf_m2R2Cag6Nw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/osaka-sushi-mundelein-2?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 196,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.2417775, 'longitude': -87.9776827},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1452 S Butterfield Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Mundelein',
#    'zip_code': '60060',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1452 S Butterfield Rd', 'Mundelein, IL 60060']},
#   'phone': '+18475499944',
#   'display_phone': '(847) 549-9944',
#   'distance': 3448.8304246598},
#  {'id': 'W4jrdps3efXU4JvHxPdBIg',
#   'alias': 'blufish-sushi-robata-vernon-hills',
#   'name': 'Blufish Sushi Robata',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lHK8HAOY_sbp65NNNQO8pw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blufish-sushi-robata-vernon-hills?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 484,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.23849454099713,
#    'longitude': -87.9478429965949},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '700 N Milwaukee Ave',
#    'address2': 'Ste 128',
#    'address3': '',
#    'city': 'Vernon Hills',
#    'zip_code': '60061',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['700 N Milwaukee Ave',
#     'Ste 128',
#     'Vernon Hills, IL 60061']},
#   'phone': '+18475493620',
#   'display_phone': '(847) 549-3620',
#   'distance': 5807.847149637726},
#  {'id': '9m_qTYOTx1BAMwggpptnrg',
#   'alias': 'vans-sushi-cafe-vernon-hills',
#   'name': "Van's Sushi Cafe",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UNNy67bMBzTxqhQhNefY5g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vans-sushi-cafe-vernon-hills?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 151,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.201184, 'longitude': -87.933535},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '1356 S Milwaukee Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Vernon Hills',
#    'zip_code': '60061',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1356 S Milwaukee Ave', 'Vernon Hills, IL 60061']},
#   'phone': '+18473836244',
#   'display_phone': '(847) 383-6244',
#   'distance': 9229.659661518983},
#  {'id': '1a9ssCh8okKaMpySZ4mIvg',
#   'alias': 'kumas-sushi-bowl-vernon-hills',
#   'name': "Kuma's Sushi Bowl",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-tFifL28ZXsoClWzd8QYtw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kumas-sushi-bowl-vernon-hills?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 240,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 42.2399892351077,
#    'longitude': -87.9416033261764},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '701 N Milwaukee Ave',
#    'address2': 'Ste 316',
#    'address3': '',
#    'city': 'Vernon Hills',
#    'zip_code': '60061',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['701 N Milwaukee Ave',
#     'Ste 316',
#     'Vernon Hills, IL 60061']},
#   'phone': '+12242067953',
#   'display_phone': '(224) 206-7953',
#   'distance': 6214.176135516486},
#  {'id': 'eRn25AfvT41vP2P_8K_4Eg',
#   'alias': 'sushi-kushi-4-u-lake-zurich',
#   'name': 'Sushi Kushi 4 U',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vK6ksbXxwyRlS_13lsTrKg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-kushi-4-u-lake-zurich?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 206,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.1962893, 'longitude': -88.1109261},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '127 S Rand Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Lake Zurich',
#    'zip_code': '60047',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['127 S Rand Rd', 'Lake Zurich, IL 60047']},
#   'phone': '+18475501250',
#   'display_phone': '(847) 550-1250',
#   'distance': 10904.54406712525},
#  {'id': 'ZBdfgSLBmE8QZl7ajb3ECw',
#   'alias': 'oishi-sushi-libertyville',
#   'name': 'Oishi Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LJTr8V4n3raNNzGCwrhhEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/oishi-sushi-libertyville?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 102,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 42.284376, 'longitude': -87.953831},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '163 N Milwaukee Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Libertyville',
#    'zip_code': '60048',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['163 N Milwaukee Ave', 'Libertyville, IL 60048']},
#   'phone': '+18472817818',
#   'display_phone': '(847) 281-7818',
#   'distance': 5460.281215906143},
#  {'id': 'Sl9cgZV8CKRxNn4bSu3iQQ',
#   'alias': 'sushi-kushi-san3-vernon-hills',
#   'name': 'Sushi Kushi San3',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DLHC1TW4tXvqtrO4Pnn2xQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-kushi-san3-vernon-hills?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 273,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 42.240036, 'longitude': -87.972296},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '281 W Townline Rd',
#    'address2': 'Unit 150',
#    'address3': '',
#    'city': 'Vernon Hills',
#    'zip_code': '60061',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['281 W Townline Rd',
#     'Unit 150',
#     'Vernon Hills, IL 60061']},
#   'phone': '+18473623330',
#   'display_phone': '(847) 362-3330',
#   'distance': 3971.7261074672097},
#  {'id': 'z30v6Tr-kAfqh14gWz_a9A',
#   'alias': 'shakou-libertyville-libertyville',
#   'name': 'Shakou-Libertyville',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MA3fb3GKOtBa2pSdSs6ssw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shakou-libertyville-libertyville?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 457,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 42.2890677, 'longitude': -87.9547897},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '625 N Milwaukee Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Libertyville',
#    'zip_code': '60048',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['625 N Milwaukee Ave', 'Libertyville, IL 60048']},
#   'phone': '+12244336675',
#   'display_phone': '(224) 433-6675',
#   'distance': 5665.7803297384135},
#  {'id': 'rFSnzCAKqajy8xLsMYdmFQ',
#   'alias': 'starfish-sushi-lincolnshire-2',
#   'name': 'Starfish Sushi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oRj_DDxvfNg2oltee_1ilA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/starfish-sushi-lincolnshire-2?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 315,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.2036299, 'longitude': -87.93211},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '185 Milwaukee Ave',
#    'address2': 'Ste 150',
#    'address3': '',
#    'city': 'Lincolnshire',
#    'zip_code': '60069',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['185 Milwaukee Ave',
#     'Ste 150',
#     'Lincolnshire, IL 60069']},
#   'phone': '+18473835511',
#   'display_phone': '(847) 383-5511',
#   'distance': 9123.340886767008},
#  {'id': 'A2OxFi_OdvgpTE1zCxVucw',
#   'alias': 'hanakawa-libertyville-2',
#   'name': 'Hanakawa',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PL2_AQDrDV8DsaM5jj9CuA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hanakawa-libertyville-2?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 206,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.27929, 'longitude': -87.95318},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '411 S Milwaukee Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Libertyville',
#    'zip_code': '60048',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['411 S Milwaukee Ave', 'Libertyville, IL 60048']},
#   'phone': '+18472470091',
#   'display_phone': '(847) 247-0091',
#   'distance': 5273.106464256689},
#  {'id': '1jxnytN20EV108D2NjXjYw',
#   'alias': 'sushi-yoru-lake-zurich',
#   'name': 'Sushi Yoru',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0PwibWmw8bty5oCmCRLnJA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-yoru-lake-zurich?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 100,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.187928, 'longitude': -88.104594},
#   'transactions': ['delivery'],
#   'location': {'address1': '523 Ela Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Lake Zurich',
#    'zip_code': '60047',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['523 Ela Rd', 'Lake Zurich, IL 60047']},
#   'phone': '+12246775353',
#   'display_phone': '(224) 677-5353',
#   'distance': 11114.483208421789},
#  {'id': 'I-OJsNtlnvwtK81s1AdEsA',
#   'alias': 'tsukasa-of-tokyo-vernon-hills',
#   'name': 'Tsukasa of Tokyo',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OQV8anUjof5q6DPFzV_DAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tsukasa-of-tokyo-vernon-hills?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 572,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 42.236277, 'longitude': -87.941708},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '561 N Milwaukee Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Vernon Hills',
#    'zip_code': '60061',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['561 N Milwaukee Ave', 'Vernon Hills, IL 60061']},
#   'phone': '+18478168770',
#   'display_phone': '(847) 816-8770',
#   'distance': 6368.576872999927},
#  {'id': 'vIjptfA0BGNmp-GmdO_esw',
#   'alias': 'tokyo-bowl-vernon-hills',
#   'name': 'Tokyo Bowl',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/as2tGSUxWBvLLOakVBV_sA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tokyo-bowl-vernon-hills?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 104,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.2405680996437,
#    'longitude': -87.9616928100586},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '121 E Townline Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Vernon Hills',
#    'zip_code': '60061',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['121 E Townline Rd', 'Vernon Hills, IL 60061']},
#   'phone': '+18475496310',
#   'display_phone': '(847) 549-6310',
#   'distance': 4684.856864829553},
#  {'id': 'M5FsGbDsZ59WJ8J4MV0n7w',
#   'alias': 'vin-90-sushi-grill-and-bar-buffalo-grove-3',
#   'name': 'Vin 90 Sushi, Grill and Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PzNB08qK0FjKF2F2_v3ujA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vin-90-sushi-grill-and-bar-buffalo-grove-3?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 16,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.19598220663925,
#    'longitude': -87.96719109758419},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '401 Half Day Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Buffalo Grove',
#    'zip_code': '60089',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['401 Half Day Rd', 'Buffalo Grove, IL 60089']},
#   'phone': '+12246760692',
#   'display_phone': '(224) 676-0692',
#   'distance': 8063.209201139692},
#  {'id': 'amYMMHe7HItgWBoJMsz8aQ',
#   'alias': 'sushi-thai-restaurant-vernon-hills',
#   'name': 'Sushi Thai Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TvdKq6xKIDZ-olTI6l-BdA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-thai-restaurant-vernon-hills?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 222,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 42.2400118318507, 'longitude': -87.953833937645},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '445 E Townline Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Vernon Hills',
#    'zip_code': '60061',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['445 E Townline Rd', 'Vernon Hills, IL 60061']},
#   'phone': '+18479682222',
#   'display_phone': '(847) 968-2222',
#   'distance': 5289.826313972036},
#  {'id': 'rWqDgFC0BoKF8Pq1xKp9gw',
#   'alias': 'sushi-thai-libertyville',
#   'name': 'Sushi Thai',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SngccXdoPjMrBCzCdq4bfg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-thai-libertyville?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 260,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 42.3046462, 'longitude': -87.958912},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1742 N Milwaukee Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Libertyville',
#    'zip_code': '60048',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1742 N Milwaukee Ave', 'Libertyville, IL 60048']},
#   'phone': '+18478164557',
#   'display_phone': '(847) 816-4557',
#   'distance': 6566.498807371016},
#  {'id': 'wCq-x5sM9xcgWIB6y0F7qg',
#   'alias': 'west-side-ramen-libertyville',
#   'name': 'West Side Ramen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gR7Vaz4cfxSitpJpU6llMw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/west-side-ramen-libertyville?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 9,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.28893, 'longitude': -87.95437},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '602 N Milwaukee Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Libertyville',
#    'zip_code': '60048',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['602 N Milwaukee Ave', 'Libertyville, IL 60048']},
#   'phone': '+12244336290',
#   'display_phone': '(224) 433-6290',
#   'distance': 5688.072485328652},
#  {'id': '7B4C4XhOo1aeIwmf8gpO2g',
#   'alias': 'dragon-star-mundelein',
#   'name': 'Dragon Star',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XWsJfXwHXxyB2yeZn00FWg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dragon-star-mundelein?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 115,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.2715187072754,
#    'longitude': -87.9941558837891},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '662 E Hawley St',
#    'address2': '',
#    'address3': None,
#    'city': 'Mundelein',
#    'zip_code': '60060',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['662 E Hawley St', 'Mundelein, IL 60060']},
#   'phone': '+18478378868',
#   'display_phone': '(847) 837-8868',
#   'distance': 1878.078750541008},
#  {'id': 'VvYtvrRnKJ8UUvJbRHYV5Q',
#   'alias': 'ramen-house-shinchan-vernon-hills',
#   'name': 'Ramen House Shinchan',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2KpWny2tY42Lv10NpEgrJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ramen-house-shinchan-vernon-hills?adjust_creative=C0qWl-nkrhgvVn4vMXVoWw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=C0qWl-nkrhgvVn4vMXVoWw',
#   'review_count': 124,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.238635, 'longitude': -87.941136},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '701 N Milwaukee Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Vernon Hills',
#    'zip_code': '60061',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['701 N Milwaukee Ave', 'Vernon Hills, IL 60061']},
#   'phone': '+18479842105',
#   'display_phone': '(847) 984-2105',
#   'distance': 6306.60895373998}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                       alias  \
# 0   jmvm1_RdsaR37hgZwaFHug                      momo-sushi-mundelein-4
# 1   FRDeSt5dcTv4bEKuaAVgkg                     osaka-sushi-mundelein-2
# 2   W4jrdps3efXU4JvHxPdBIg           blufish-sushi-robata-vernon-hills
# 3   9m_qTYOTx1BAMwggpptnrg                vans-sushi-cafe-vernon-hills
# 4   1a9ssCh8okKaMpySZ4mIvg               kumas-sushi-bowl-vernon-hills
# 5   eRn25AfvT41vP2P_8K_4Eg                 sushi-kushi-4-u-lake-zurich
# 6   ZBdfgSLBmE8QZl7ajb3ECw                    oishi-sushi-libertyville
# 7   Sl9cgZV8CKRxNn4bSu3iQQ               sushi-kushi-san3-vernon-hills
# 8   z30v6Tr-kAfqh14gWz_a9A            shakou-libertyville-libertyville
# 9   rFSnzCAKqajy8xLsMYdmFQ               starfish-sushi-lincolnshire-2
# 10  A2OxFi_OdvgpTE1zCxVucw                     hanakawa-libertyville-2
# 11  1jxnytN20EV108D2NjXjYw                      sushi-yoru-lake-zurich
# 12  I-OJsNtlnvwtK81s1AdEsA               tsukasa-of-tokyo-vernon-hills
# 13  vIjptfA0BGNmp-GmdO_esw                     tokyo-bowl-vernon-hills
# 14  M5FsGbDsZ59WJ8J4MV0n7w  vin-90-sushi-grill-and-bar-buffalo-grove-3
# 15  amYMMHe7HItgWBoJMsz8aQ          sushi-thai-restaurant-vernon-hills
# 16  rWqDgFC0BoKF8Pq1xKp9gw                     sushi-thai-libertyville
# 17  wCq-x5sM9xcgWIB6y0F7qg                west-side-ramen-libertyville
# 18  7B4C4XhOo1aeIwmf8gpO2g                       dragon-star-mundelein
# 19  VvYtvrRnKJ8UUvJbRHYV5Q           ramen-house-shinchan-vernon-hills
#
#                            name  \
# 0                    Momo sushi
# 1                   Osaka Sushi
# 2          Blufish Sushi Robata
# 3              Van's Sushi Cafe
# 4             Kuma's Sushi Bowl
# 5               Sushi Kushi 4 U
# 6                   Oishi Sushi
# 7              Sushi Kushi San3
# 8           Shakou-Libertyville
# 9                Starfish Sushi
# 10                     Hanakawa
# 11                   Sushi Yoru
# 12             Tsukasa of Tokyo
# 13                   Tokyo Bowl
# 14  Vin 90 Sushi, Grill and Bar
# 15        Sushi Thai Restaurant
# 16                   Sushi Thai
# 17              West Side Ramen
# 18                  Dragon Star
# 19         Ramen House Shinchan
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/Mbrlz_...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/T93W-K...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/lHK8HA...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/UNNy67...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/-tFifL...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/vK6ksb...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/LJTr8V...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/DLHC1T...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/MA3fb3...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/oRj_DD...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/PL2_AQ...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/0PwibW...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/OQV8an...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/as2tGS...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/PzNB08...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/TvdKq6...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/SngccX...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/gR7Vaz...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/XWsJfX...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/2KpWny...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/momo-sushi-mundelein-...            49
# 1   https://www.yelp.com/biz/osaka-sushi-mundelein...           196
# 2   https://www.yelp.com/biz/blufish-sushi-robata-...           484
# 3   https://www.yelp.com/biz/vans-sushi-cafe-verno...           151
# 4   https://www.yelp.com/biz/kumas-sushi-bowl-vern...           240
# 5   https://www.yelp.com/biz/sushi-kushi-4-u-lake-...           206
# 6   https://www.yelp.com/biz/oishi-sushi-libertyvi...           102
# 7   https://www.yelp.com/biz/sushi-kushi-san3-vern...           273
# 8   https://www.yelp.com/biz/shakou-libertyville-l...           457
# 9   https://www.yelp.com/biz/starfish-sushi-lincol...           315
# 10  https://www.yelp.com/biz/hanakawa-libertyville...           206
# 11  https://www.yelp.com/biz/sushi-yoru-lake-zuric...           100
# 12  https://www.yelp.com/biz/tsukasa-of-tokyo-vern...           572
# 13  https://www.yelp.com/biz/tokyo-bowl-vernon-hil...           104
# 14  https://www.yelp.com/biz/vin-90-sushi-grill-an...            16
# 15  https://www.yelp.com/biz/sushi-thai-restaurant...           222
# 16  https://www.yelp.com/biz/sushi-thai-libertyvil...           260
# 17  https://www.yelp.com/biz/west-side-ramen-liber...             9
# 18  https://www.yelp.com/biz/dragon-star-mundelein...           115
# 19  https://www.yelp.com/biz/ramen-house-shinchan-...           124
#
#                                            categories  rating  \
# 0         [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.0
# 1   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 2   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 3         [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.5
# 4         [{'alias': 'sushi', 'title': 'Sushi Bars'}]     5.0
# 5   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 6   [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 7   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
# 8   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
# 9   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 10  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 11  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 12       [{'alias': 'japanese', 'title': 'Japanese'}]     3.5
# 13       [{'alias': 'japanese', 'title': 'Japanese'}]     4.0
# 14  [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.5
# 15  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 16  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
# 17  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.0
# 18         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 19             [{'alias': 'ramen', 'title': 'Ramen'}]     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 42.25337483, 'longitude': -88.001...  [delivery, pickup]
# 1   {'latitude': 42.2417775, 'longitude': -87.9776...  [delivery, pickup]
# 2   {'latitude': 42.23849454099713, 'longitude': -...  [delivery, pickup]
# 3    {'latitude': 42.201184, 'longitude': -87.933535}  [delivery, pickup]
# 4   {'latitude': 42.2399892351077, 'longitude': -8...  [delivery, pickup]
# 5   {'latitude': 42.1962893, 'longitude': -88.1109...          [delivery]
# 6    {'latitude': 42.284376, 'longitude': -87.953831}          [delivery]
# 7    {'latitude': 42.240036, 'longitude': -87.972296}  [delivery, pickup]
# 8   {'latitude': 42.2890677, 'longitude': -87.9547...  [delivery, pickup]
# 9    {'latitude': 42.2036299, 'longitude': -87.93211}  [delivery, pickup]
# 10     {'latitude': 42.27929, 'longitude': -87.95318}          [delivery]
# 11   {'latitude': 42.187928, 'longitude': -88.104594}          [delivery]
# 12   {'latitude': 42.236277, 'longitude': -87.941708}  [delivery, pickup]
# 13  {'latitude': 42.2405680996437, 'longitude': -8...          [delivery]
# 14  {'latitude': 42.19598220663925, 'longitude': -...  [delivery, pickup]
# 15  {'latitude': 42.2400118318507, 'longitude': -8...  [delivery, pickup]
# 16  {'latitude': 42.3046462, 'longitude': -87.958912}  [delivery, pickup]
# 17     {'latitude': 42.28893, 'longitude': -87.95437}  [delivery, pickup]
# 18  {'latitude': 42.2715187072754, 'longitude': -8...  [delivery, pickup]
# 19   {'latitude': 42.238635, 'longitude': -87.941136}  [delivery, pickup]
#
#                                              location         phone  \
# 0   {'address1': '662 S Lake St', 'address2': '', ...  +18475662544
# 1   {'address1': '1452 S Butterfield Rd', 'address...  +18475499944
# 2   {'address1': '700 N Milwaukee Ave', 'address2'...  +18475493620
# 3   {'address1': '1356 S Milwaukee Ave', 'address2...  +18473836244
# 4   {'address1': '701 N Milwaukee Ave', 'address2'...  +12242067953
# 5   {'address1': '127 S Rand Rd', 'address2': None...  +18475501250
# 6   {'address1': '163 N Milwaukee Ave', 'address2'...  +18472817818
# 7   {'address1': '281 W Townline Rd', 'address2': ...  +18473623330
# 8   {'address1': '625 N Milwaukee Ave', 'address2'...  +12244336675
# 9   {'address1': '185 Milwaukee Ave', 'address2': ...  +18473835511
# 10  {'address1': '411 S Milwaukee Ave', 'address2'...  +18472470091
# 11  {'address1': '523 Ela Rd', 'address2': '', 'ad...  +12246775353
# 12  {'address1': '561 N Milwaukee Ave', 'address2'...  +18478168770
# 13  {'address1': '121 E Townline Rd', 'address2': ...  +18475496310
# 14  {'address1': '401 Half Day Rd', 'address2': No...  +12246760692
# 15  {'address1': '445 E Townline Rd', 'address2': ...  +18479682222
# 16  {'address1': '1742 N Milwaukee Ave', 'address2...  +18478164557
# 17  {'address1': '602 N Milwaukee Ave', 'address2'...  +12244336290
# 18  {'address1': '662 E Hawley St', 'address2': ''...  +18478378868
# 19  {'address1': '701 N Milwaukee Ave', 'address2'...  +18479842105
#
#      display_phone      distance price
# 0   (847) 566-2544   1158.842622   NaN
# 1   (847) 549-9944   3448.830425    $$
# 2   (847) 549-3620   5807.847150    $$
# 3   (847) 383-6244   9229.659662   NaN
# 4   (224) 206-7953   6214.176136    $$
# 5   (847) 550-1250  10904.544067    $$
# 6   (847) 281-7818   5460.281216    $$
# 7   (847) 362-3330   3971.726107    $$
# 8   (224) 433-6675   5665.780330    $$
# 9   (847) 383-5511   9123.340887    $$
# 10  (847) 247-0091   5273.106464    $$
# 11  (224) 677-5353  11114.483208   NaN
# 12  (847) 816-8770   6368.576873    $$
# 13  (847) 549-6310   4684.856865    $$
# 14  (224) 676-0692   8063.209201   NaN
# 15  (847) 968-2222   5289.826314    $$
# 16  (847) 816-4557   6566.498807    $$
# 17  (224) 433-6290   5688.072485   NaN
# 18  (847) 837-8868   1878.078751     $
# 19  (847) 984-2105   6306.608954    $$

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
(results['total'])/ results_per_page
# Out:
# 1.85

# %%
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 2

# %%
for i in tqdm_notebook(range(1, n_pages+1)):
    try:
        time.sleep(.2)
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        n_results = len(previous_results)
        results = yelp.search_query(location = location, term = term, 
                                    offset= n_results+1)
        previous_results.extend(results['businesses'])
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)
    except Exception as e:
        print (' [!] ERROR', e)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
df = pd.read_json(JSON_FILE)
df.head()
# Out:
#                        id                              alias  \
# 0  FRDeSt5dcTv4bEKuaAVgkg            osaka-sushi-mundelein-2
# 1  W4jrdps3efXU4JvHxPdBIg  blufish-sushi-robata-vernon-hills
# 2  9m_qTYOTx1BAMwggpptnrg       vans-sushi-cafe-vernon-hills
# 3  1a9ssCh8okKaMpySZ4mIvg      kumas-sushi-bowl-vernon-hills
# 4  eRn25AfvT41vP2P_8K_4Eg        sushi-kushi-4-u-lake-zurich
#
#                    name                                          image_url  \
# 0           Osaka Sushi  https://s3-media3.fl.yelpcdn.com/bphoto/T93W-K...
# 1  Blufish Sushi Robata  https://s3-media2.fl.yelpcdn.com/bphoto/lHK8HA...
# 2      Van's Sushi Cafe  https://s3-media3.fl.yelpcdn.com/bphoto/UNNy67...
# 3     Kuma's Sushi Bowl  https://s3-media4.fl.yelpcdn.com/bphoto/-tFifL...
# 4       Sushi Kushi 4 U  https://s3-media2.fl.yelpcdn.com/bphoto/vK6ksb...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/osaka-sushi-mundelein...           196
# 1      False  https://www.yelp.com/biz/blufish-sushi-robata-...           484
# 2      False  https://www.yelp.com/biz/vans-sushi-cafe-verno...           151
# 3      False  https://www.yelp.com/biz/kumas-sushi-bowl-vern...           240
# 4      False  https://www.yelp.com/biz/sushi-kushi-4-u-lake-...           206
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 1  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 2        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.5
# 3        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     5.0
# 4  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 42.2417775, 'longitude': -87.9776...  [delivery, pickup]
# 1  {'latitude': 42.23849454099713, 'longitude': -...  [delivery, pickup]
# 2   {'latitude': 42.201184, 'longitude': -87.933535}  [delivery, pickup]
# 3  {'latitude': 42.2399892351077, 'longitude': -8...  [delivery, pickup]
# 4  {'latitude': 42.1962893, 'longitude': -88.1109...          [delivery]
#
#   price                                           location        phone  \
# 0    $$  {'address1': '1452 S Butterfield Rd', 'address...  18475499944
# 1    $$  {'address1': '700 N Milwaukee Ave', 'address2'...  18475493620
# 2   NaN  {'address1': '1356 S Milwaukee Ave', 'address2...  18473836244
# 3    $$  {'address1': '701 N Milwaukee Ave', 'address2'...  12242067953
# 4    $$  {'address1': '127 S Rand Rd', 'address2': None...  18475501250
#
#     display_phone      distance
# 0  (847) 549-9944   3448.830425
# 1  (847) 549-3620   5807.847150
# 2  (847) 383-6244   9229.659662
# 3  (224) 206-7953   6214.176136
# 4  (847) 550-1250  10904.544067

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             36 non-null     object
#  1   alias          36 non-null     object
#  2   name           36 non-null     object
#  3   image_url      36 non-null     object
#  4   is_closed      36 non-null     bool
#  5   url            36 non-null     object
#  6   review_count   36 non-null     int64
#  7   categories     36 non-null     object
#  8   rating         36 non-null     float64
#  9   coordinates    36 non-null     object
#  10  transactions   36 non-null     object
#  11  price          30 non-null     object
#  12  location       36 non-null     object
#  13  phone          36 non-null     int64
#  14  display_phone  36 non-null     object
#  15  distance       36 non-null     float64
# dtypes: bool(1), float64(2), int64(2), object(11)
# memory usage: 4.4+ KB

# %%
csv_file = JSON_FILE.replace('.json', '.csv.gz')
csv_file
# Out:
# 'Data/Mundelein-sushi.csv.gz'

# %%
df.to_csv(csv_file, compression = 'gzip', index = False)
